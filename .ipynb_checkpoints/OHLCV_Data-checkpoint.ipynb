# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import ccxt
import requests
import json

# %%
print(ccxt.exchanges)
exchange_list = ccxt.exchanges
# Out:
# ['_1broker', '_1btcxe', 'acx', 'allcoin', 'anxpro', 'bibox', 'binance', 'bit2c', 'bitbank', 'bitbay', 'bitfinex', 'bitfinex2', 'bitflyer', 'bithumb', 'bitkk', 'bitlish', 'bitmarket', 'bitmex', 'bitso', 'bitstamp', 'bitstamp1', 'bittrex', 'bitz', 'bl3p', 'bleutrade', 'braziliex', 'btcbox', 'btcchina', 'btcexchange', 'btcmarkets', 'btctradeim', 'btctradeua', 'btcturk', 'btcx', 'bxinth', 'ccex', 'cex', 'chbtc', 'chilebit', 'cobinhood', 'coincheck', 'coinegg', 'coinex', 'coinexchange', 'coinfloor', 'coingi', 'coinmarketcap', 'coinmate', 'coinnest', 'coinone', 'coinsecure', 'coinspot', 'coolcoin', 'cryptopia', 'dsx', 'ethfinex', 'exmo', 'exx', 'flowbtc', 'foxbit', 'fybse', 'fybsg', 'gatecoin', 'gateio', 'gdax', 'gemini', 'getbtc', 'hadax', 'hitbtc', 'hitbtc2', 'huobi', 'huobicny', 'huobipro', 'ice3x', 'independentreserve', 'indodax', 'itbit', 'jubi', 'kraken', 'kucoin', 'kuna', 'lakebtc', 'lbank', 'liqui', 'livecoin', 'luno', 'lykke', 'mercado', 'mixcoins', 'negociecoins', 'nova', 'okcoincny', 'okcoinusd', 'okex', 'paymium', 'poloniex', 'qryptos', 'quadrigacx', 'quoinex', 'southxchange', 'surbitcoin', 'therock', 'tidebit', 'tidex', 'urdubit', 'vaultoro', 'vbtc', 'virwox', 'wex', 'xbtce', 'yobit', 'yunbi', 'zaif', 'zb']

# %%
# ?ccxt
# Out:
# Type:        module
# String form: <module 'ccxt' from 'c:\\users\\garrick\\anaconda3\\envs\\tensorflow\\lib\\site-packages\\ccxt\\__init__.py'>
# File:        c:\users\garrick\anaconda3\envs\tensorflow\lib\site-packages\ccxt\__init__.py
# Docstring:   CCXT: CryptoCurrency eXchange Trading Library

# %%
req = requests.get('http://coincap.io/front')

# %%
coin_json = req.json()

# %%
coin_df = pd.DataFrame(coin_json)

# %%
coin_df.head()
# Out:
#    cap24hrChange          long        mktcap   perc        price  shapeshift  \
# 0           3.15       Bitcoin  1.604834e+11   3.15  9432.910000        True
# 1          11.01      Ethereum  7.491658e+10  11.01   755.157000        True
# 2           3.33        Ripple  3.445081e+10   3.33     0.879883        True
# 3           4.02  Bitcoin Cash  2.592824e+10   4.02  1515.590000        True
# 4          -4.96           EOS  1.478897e+10  -4.96    17.755900        True
#
#   short       supply     usdVolume        volume     vwapData  vwapDataBTC
# 0   BTC     17013137  8.824850e+09  8.824850e+09  9273.444148  9273.444148
# 1   ETH     99206629  3.619800e+09  3.619800e+09   713.121094   713.121094
# 2   XRP  39153851043  6.076360e+08  6.076360e+08     0.858228     0.858228
# 3   BCH     17107688  1.203700e+09  1.203700e+09  1501.659883  1501.659883
# 4   EOS    832904338  2.016170e+09  2.016170e+09    18.322640    18.322640

# %%
coin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1296 entries, 0 to 1295
# Data columns (total 12 columns):
# cap24hrChange    1296 non-null float64
# long             1296 non-null object
# mktcap           1296 non-null float64
# perc             1296 non-null float64
# price            1296 non-null float64
# shapeshift       1296 non-null bool
# short            1296 non-null object
# supply           1296 non-null int64
# usdVolume        1296 non-null float64
# volume           1296 non-null float64
# vwapData         1296 non-null float64
# vwapDataBTC      1296 non-null float64
# dtypes: bool(1), float64(8), int64(1), object(2)
# memory usage: 112.7+ KB

# %%
set(coin_df.isnull().sum())
# Out:
# {0}

# %% [markdown]
# Data looks good, no nulls.  OK to begin sort by market cap (need top 500 coins).  Export this out as master coin JSON, later need script to add if new coin etners top 500.

# %%
coin_df.sort_values('mktcap', ascending=False)
coin_df.head(10)
# Out:
#    cap24hrChange          long        mktcap   perc        price  shapeshift  \
# 0           3.15       Bitcoin  1.604834e+11   3.15  9432.910000        True
# 1          11.01      Ethereum  7.491658e+10  11.01   755.157000        True
# 2           3.33        Ripple  3.445081e+10   3.33     0.879883        True
# 3           4.02  Bitcoin Cash  2.592824e+10   4.02  1515.590000        True
# 4          -4.96           EOS  1.478897e+10  -4.96    17.755900        True
# 5           1.02       Cardano  9.735796e+09   1.02     0.375507       False
# 6           8.57      Litecoin  9.119766e+09   8.57   161.800000        True
# 7          -0.12       Stellar  8.136266e+09  -0.12     0.438095       False
# 8          21.14          IOTA  7.218607e+09  21.14     2.597060       False
# 9          -3.80          TRON  5.747720e+09  -3.80     0.087420       False
#
#   short       supply     usdVolume        volume     vwapData  vwapDataBTC
# 0   BTC     17013137  8.824850e+09  8.824850e+09  9273.444148  9273.444148
# 1   ETH     99206629  3.619800e+09  3.619800e+09   713.121094   713.121094
# 2   XRP  39153851043  6.076360e+08  6.076360e+08     0.858228     0.858228
# 3   BCH     17107688  1.203700e+09  1.203700e+09  1501.659883  1501.659883
# 4   EOS    832904338  2.016170e+09  2.016170e+09    18.322640    18.322640
# 5   ADA  25927070538  2.908390e+08  2.908390e+08     0.372699     0.372699
# 6   LTC     56364438  5.486140e+08  5.486140e+08   152.583302   152.583302
# 7   XLM  18571922373  6.970940e+07  6.970940e+07     0.435519     0.435519
# 8   IOT   2779530283  3.434040e+08  3.434040e+08     2.409267     2.409267
# 9   TRX  65748111645  6.512790e+08  6.512790e+08     0.089059     0.089059

# %%
# let's find % of total coin market cap
total_market = coin_df['mktcap'].sum()

# %%
coin_df['pct_total_market'] = (coin_df['mktcap'] / total_market)*100

# %%
coin_df.columns
# Out:
# Index(['cap24hrChange', 'long', 'mktcap', 'perc', 'price', 'shapeshift',
#        'short', 'supply', 'usdVolume', 'volume', 'vwapData', 'vwapDataBTC',
#        'pct_total_market'],
#       dtype='object')

# %%
coin_df.head()
# Out:
#    cap24hrChange          long        mktcap   perc        price  shapeshift  \
# 0           1.37       Bitcoin  1.554147e+11   1.37  9135.880000        True
# 1           2.34      Ethereum  6.719798e+10   2.34   677.480000        True
# 2           2.18        Ripple  3.332459e+10   2.18     0.851119        True
# 3          12.44  Bitcoin Cash  2.488636e+10  12.44  1454.830000        True
# 4           6.66           EOS  1.546267e+10   6.66    18.609600        True
#
#   short       supply     usdVolume        volume     vwapData  vwapDataBTC  \
# 0   BTC     17011462  6.812190e+09  6.812190e+09  9104.188095  9104.188095
# 1   ETH     99188143  2.415890e+09  2.415890e+09   675.436734   675.436734
# 2   XRP  39153851043  5.307420e+08  5.307420e+08     0.844074     0.844074
# 3   BCH     17106025  1.146200e+09  1.146200e+09  1417.280572  1417.280572
# 4   EOS    830897534  2.167910e+09  2.167910e+09    18.443880    18.443880
#
#    pct_total_market
# 0         36.181475
# 1         15.644096
# 2          7.758165
# 3          5.793694
# 4          3.599803

# %%
coin_df[:500].head()
# Out:
#    cap24hrChange          long        mktcap   perc        price  shapeshift  \
# 0           1.37       Bitcoin  1.554147e+11   1.37  9135.880000        True
# 1           2.34      Ethereum  6.719798e+10   2.34   677.480000        True
# 2           2.18        Ripple  3.332459e+10   2.18     0.851119        True
# 3          12.44  Bitcoin Cash  2.488636e+10  12.44  1454.830000        True
# 4           6.66           EOS  1.546267e+10   6.66    18.609600        True
#
#   short       supply     usdVolume        volume     vwapData  vwapDataBTC  \
# 0   BTC     17011462  6.812190e+09  6.812190e+09  9104.188095  9104.188095
# 1   ETH     99188143  2.415890e+09  2.415890e+09   675.436734   675.436734
# 2   XRP  39153851043  5.307420e+08  5.307420e+08     0.844074     0.844074
# 3   BCH     17106025  1.146200e+09  1.146200e+09  1417.280572  1417.280572
# 4   EOS    830897534  2.167910e+09  2.167910e+09    18.443880    18.443880
#
#    pct_total_market
# 0         36.181475
# 1         15.644096
# 2          7.758165
# 3          5.793694
# 4          3.599803

# %%
plt.style.use('bmh')

font = {'family' : 'sans-serif',
        'weight' : 'medium',
        'size'   : 16}

plt.rc('font', **font)
plt.rcParams['figure.figsize'] = (10.0, 10.0)

# %%
_ = plt.pie(x=coin_df['mktcap'], labels=coin_df['long'], autopct='%1.1f%%')
_ = plt.title('% Market Cap of Top 500 Coins')

# %%
_ = plt.pie(x=coin_df['mktcap'].head(10), labels=coin_df['long'].head(10), autopct='%1.1f%%')
_ = plt.title('% Market Cap of Top 10 Coins')

# %%
# synthesize new dataframe, adding ticker column and timestamp

coin_list = coin_df[['long', 'short']][:500]
coin_list['ticker'] = coin_list['short'] + "/USD"
coin_list['timestamp'] = pd.Timestamp.now()
coin_list.tail()
# Out:
#                  long  short     ticker                  timestamp
# 495       NoLimitCoin   NLC2   NLC2/USD 2018-05-03 09:52:15.815425
# 496             Hedge    HDG    HDG/USD 2018-05-03 09:52:15.815425
# 497  Nimiq Exchang...    NET    NET/USD 2018-05-03 09:52:15.815425
# 498             Polis  POLIS  POLIS/USD 2018-05-03 09:52:15.815425
# 499          Musicoin  MUSIC  MUSIC/USD 2018-05-03 09:52:15.815425

# %%
# load in master coin list

master_list = pd.read_csv('top_500_coins.csv', index_col=0)
# Out:
#            long short   ticker                   timestamp
# 0       Bitcoin   BTC  BTC/USD  2018-05-02 12:20:06.608871
# 1      Ethereum   ETH  ETH/USD  2018-05-02 12:20:06.608871
# 2        Ripple   XRP  XRP/USD  2018-05-02 12:20:06.608871
# 3  Bitcoin Cash   BCH  BCH/USD  2018-05-02 12:20:06.608871
# 4           EOS   EOS  EOS/USD  2018-05-02 12:20:06.608871

# %%
# compare and append

updated_list = pd.concat([master_list, coin_list], ignore_index=False).drop_duplicates(subset=['short'], keep='first', inplace=False).reset_index(drop=True)

# %%
updated_list
# Out:
#                  long   short      ticker                   timestamp
# 0             Bitcoin     BTC     BTC/USD  2018-05-02 12:20:06.608871
# 1            Ethereum     ETH     ETH/USD  2018-05-02 12:20:06.608871
# 2              Ripple     XRP     XRP/USD  2018-05-02 12:20:06.608871
# 3        Bitcoin Cash     BCH     BCH/USD  2018-05-02 12:20:06.608871
# 4                 EOS     EOS     EOS/USD  2018-05-02 12:20:06.608871
# 5             Cardano     ADA     ADA/USD  2018-05-02 12:20:06.608871
# 6            Litecoin     LTC     LTC/USD  2018-05-02 12:20:06.608871
# 7             Stellar     XLM     XLM/USD  2018-05-02 12:20:06.608871
# 8                IOTA     IOT     IOT/USD  2018-05-02 12:20:06.608871
# 9                TRON     TRX     TRX/USD  2018-05-02 12:20:06.608871
# 10                NEO     NEO     NEO/USD  2018-05-02 12:20:06.608871
# 11             Monero     XMR     XMR/USD  2018-05-02 12:20:06.608871
# 12               Dash    DASH    DASH/USD  2018-05-02 12:20:06.608871
# 13                NEM     XEM     XEM/USD  2018-05-02 12:20:06.608871
# 14            VeChain     VEN     VEN/USD  2018-05-02 12:20:06.608871
# 15             Tether    USDT    USDT/USD  2018-05-02 12:20:06.608871
# 16   Ethereum Classic     ETC     ETC/USD  2018-05-02 12:20:06.608871
# 17               Qtum    QTUM    QTUM/USD  2018-05-02 12:20:06.608871
# 18            OmiseGO     OMG     OMG/USD  2018-05-02 12:20:06.608871
# 19               ICON     ICX     ICX/USD  2018-05-02 12:20:06.608871
# 20       Binance Coin     BNB     BNB/USD  2018-05-02 12:20:06.608871
# 21               Lisk     LSK     LSK/USD  2018-05-02 12:20:06.608871
# 22       Bitcoin Gold     BTG     BTG/USD  2018-05-02 12:20:06.608871
# 23              Verge     XVG     XVG/USD  2018-05-02 12:20:06.608871
# 24              Zcash     ZEC     ZEC/USD  2018-05-02 12:20:06.608871
# 25               Nano    NANO    NANO/USD  2018-05-02 12:20:06.608871
# 26          Aeternity      AE      AE/USD  2018-05-02 12:20:06.608871
# 27              Steem   STEEM   STEEM/USD  2018-05-02 12:20:06.608871
# 28           Bytecoin     BCN     BCN/USD  2018-05-02 12:20:06.608871
# 29          BitShares     BTS     BTS/USD  2018-05-02 12:20:06.608871
# ..                ...     ...         ...                         ...
# 479        Swarm City     SWT     SWT/USD  2018-05-02 12:20:06.608871
# 480         Boolberry     BBR     BBR/USD  2018-05-02 12:20:06.608871
# 481              REBL    REBL    REBL/USD  2018-05-02 12:20:06.608871
# 482            Auctus     AUC     AUC/USD  2018-05-02 12:20:06.608871
# 483         Effect.AI     EFX     EFX/USD  2018-05-02 12:20:06.608871
# 484          Etheroll    DICE    DICE/USD  2018-05-02 12:20:06.608871
# 485   FintruX Network     FTX     FTX/USD  2018-05-02 12:20:06.608871
# 486           Debitum     DEB     DEB/USD  2018-05-02 12:20:06.608871
# 487       FoldingCoin    FLDC    FLDC/USD  2018-05-02 12:20:06.608871
# 488              MUSE    MUSE    MUSE/USD  2018-05-02 12:20:06.608871
# 489            Everus     EVR     EVR/USD  2018-05-02 12:20:06.608871
# 490           Payfair     PFR     PFR/USD  2018-05-02 12:20:06.608871
# 491            Snovio    SNOV    SNOV/USD  2018-05-02 12:20:06.608871
# 492          Musicoin   MUSIC   MUSIC/USD  2018-05-02 12:20:06.608871
# 493            Cashaa     CAS     CAS/USD  2018-05-02 12:20:06.608871
# 494         CoinPoker     CHP     CHP/USD  2018-05-02 12:20:06.608871
# 495            CVCoin  CVCOIN  CVCOIN/USD  2018-05-02 12:20:06.608871
# 496       Block Array     ARY     ARY/USD  2018-05-02 12:20:06.608871
# 497       NoLimitCoin    NLC2    NLC2/USD  2018-05-02 12:20:06.608871
# 498         DomRaider     DRT     DRT/USD  2018-05-02 12:20:06.608871
# 499          Bounty0x    BNTY    BNTY/USD  2018-05-02 12:20:06.608871
# 500    BnkToTheFuture     BFT     BFT/USD  2018-05-03 09:52:15.815425
# 501          BitClave     CAT     CAT/USD  2018-05-03 09:52:15.815425
# 502      Lendingblock     LND     LND/USD  2018-05-03 09:52:15.815425
# 503           ATBCoin     ATB     ATB/USD  2018-05-03 09:52:15.815425
# 504          Maecenas     ART     ART/USD  2018-05-03 09:52:15.815425
# 505              Dovu    DOVU    DOVU/USD  2018-05-03 09:52:15.815425
# 506              Pure    PURE    PURE/USD  2018-05-03 09:52:15.815425
# 507             Hedge     HDG     HDG/USD  2018-05-03 09:52:15.815425
# 508             Polis   POLIS   POLIS/USD  2018-05-03 09:52:15.815425
#
# [509 rows x 4 columns]

# %%
# export coin_list as csv

updated_list.to_csv('top_coins.csv', mode='w')

# long = coin's long name
# short = coin's short name
# ticker = coin's ticker, short name in USD base
# timestamp = time added to list

# %%
# need to write code here to import back in CSV for production

# %%
import time

# %%
# now that we have a list of top 500 coins, use a reference table to iterate or join over for the CCXT library
# construct dataframe to fill and append OHLCV values, multi-index. 
# first level = ticker, second level = exchange

# construct multi level index, per coin ticker per exchange
index = pd.MultiIndex.from_product([updated_list['ticker'].tolist(), top_exchanges], names=['Ticker','Exchange'] )

# %%
# construct column labels

periods = ['5m','15m','30m', '1h','4h','12h','24h','72h','1w']
vals = ['Open','High','Low','Close','Volume']
cols = [x+'_'+y for y in periods for x in vals]

# %%
# construct elements into empty DF

ohlcv_df = pd.DataFrame(index=index, columns=cols)
ohlcv_df.head()
# Out:
#                  Open_5m High_5m Low_5m Close_5m Volume_5m Open_15m High_15m  \
# Ticker  Exchange
# BTC/USD binance      NaN     NaN    NaN      NaN       NaN      NaN      NaN
#         bitmex       NaN     NaN    NaN      NaN       NaN      NaN      NaN
#         okex         NaN     NaN    NaN      NaN       NaN      NaN      NaN
#         huobi        NaN     NaN    NaN      NaN       NaN      NaN      NaN
#         cex          NaN     NaN    NaN      NaN       NaN      NaN      NaN
#
#                  Low_15m Close_15m Volume_15m    ...    Open_72h High_72h  \
# Ticker  Exchange                                 ...
# BTC/USD binance      NaN       NaN        NaN    ...         NaN      NaN
#         bitmex       NaN       NaN        NaN    ...         NaN      NaN
#         okex         NaN       NaN        NaN    ...         NaN      NaN
#         huobi        NaN       NaN        NaN    ...         NaN      NaN
#         cex          NaN       NaN        NaN    ...         NaN      NaN
#
#                  Low_72h Close_72h Volume_72h Open_1w High_1w Low_1w Close_1w  \
# Ticker  Exchange
# BTC/USD binance      NaN       NaN        NaN     NaN     NaN    NaN      NaN
#         bitmex       NaN       NaN        NaN     NaN     NaN    NaN      NaN
#         okex         NaN       NaN        NaN     NaN     NaN    NaN      NaN
#         huobi        NaN       NaN        NaN     NaN     NaN    NaN      NaN
#         cex          NaN       NaN        NaN     NaN     NaN    NaN      NaN
#
#                  Volume_1w
# Ticker  Exchange
# BTC/USD binance        NaN
#         bitmex         NaN
#         okex           NaN
#         huobi          NaN
#         cex            NaN
#
# [5 rows x 45 columns]

# %% [markdown]
# Note: fetchOHLCV (symbol, timeframe = '1m', since = undefined, limit = undefined, params = {})

# %%
exchange_list
# Out:
# ['_1broker',
#  '_1btcxe',
#  'acx',
#  'allcoin',
#  'anxpro',
#  'bibox',
#  'binance',
#  'bit2c',
#  'bitbank',
#  'bitbay',
#  'bitfinex',
#  'bitfinex2',
#  'bitflyer',
#  'bithumb',
#  'bitkk',
#  'bitlish',
#  'bitmarket',
#  'bitmex',
#  'bitso',
#  'bitstamp',
#  'bitstamp1',
#  'bittrex',
#  'bitz',
#  'bl3p',
#  'bleutrade',
#  'braziliex',
#  'btcbox',
#  'btcchina',
#  'btcexchange',
#  'btcmarkets',
#  'btctradeim',
#  'btctradeua',
#  'btcturk',
#  'btcx',
#  'bxinth',
#  'ccex',
#  'cex',
#  'chbtc',
#  'chilebit',
#  'cobinhood',
#  'coincheck',
#  'coinegg',
#  'coinex',
#  'coinexchange',
#  'coinfloor',
#  'coingi',
#  'coinmarketcap',
#  'coinmate',
#  'coinnest',
#  'coinone',
#  'coinsecure',
#  'coinspot',
#  'coolcoin',
#  'cryptopia',
#  'dsx',
#  'ethfinex',
#  'exmo',
#  'exx',
#  'flowbtc',
#  'foxbit',
#  'fybse',
#  'fybsg',
#  'gatecoin',
#  'gateio',
#  'gdax',
#  'gemini',
#  'getbtc',
#  'hadax',
#  'hitbtc',
#  'hitbtc2',
#  'huobi',
#  'huobicny',
#  'huobipro',
#  'ice3x',
#  'independentreserve',
#  'indodax',
#  'itbit',
#  'jubi',
#  'kraken',
#  'kucoin',
#  'kuna',
#  'lakebtc',
#  'lbank',
#  'liqui',
#  'livecoin',
#  'luno',
#  'lykke',
#  'mercado',
#  'mixcoins',
#  'negociecoins',
#  'nova',
#  'okcoincny',
#  'okcoinusd',
#  'okex',
#  'paymium',
#  'poloniex',
#  'qryptos',
#  'quadrigacx',
#  'quoinex',
#  'southxchange',
#  'surbitcoin',
#  'therock',
#  'tidebit',
#  'tidex',
#  'urdubit',
#  'vaultoro',
#  'vbtc',
#  'virwox',
#  'wex',
#  'xbtce',
#  'yobit',
#  'yunbi',
#  'zaif',
#  'zb']

# %%
# might prove too difficult to do all the exchanges, even if public API, some need login....
# top exchanges where total volume >$150MM

top_exchanges = ['binance', 'bitmex', 'okex','huobi', 'cex', 'bitfinex', 'bithumb','bittrex','lbank',
                 'bitz','gdax','hitbtc','kraken','gateio', 'bitstamp','bibox','exx']

# %%
# will need to write a for-loop to iterate over each ticker

# testing architecture for single coin

exchange = ccxt.gdax()
markets = exchange.load_markets()

# %%
ccxt.gdax.has['fetchOHLCV']
# Out:
# 'emulated'

# %%
ohlcv = exchange.fetch_ohlcv('BTC/USD', timeframe='1d', limit=10)

# %%
ohlcv[0][1:]
# Out:
# [9072.29, 9251.05, 8990, 9190.48, 8818.065521590823]

# %%
cols = ['time', 'open','high','low','close','vol']

df = pd.DataFrame(ohlcv, columns=cols)
df['time'] = pd.to_datetime(df['time'], unit='ms')
df.head()
# Out:
#         time     open     high      low    close           vol
# 0 2018-05-02  9072.29  9251.05  8990.00  9190.48   8818.065522
# 1 2018-05-01  9243.83  9245.37  8831.21  9072.29  11372.350451
# 2 2018-04-30  9389.01  9447.00  9110.88  9243.82   8862.185301
# 3 2018-04-29  9329.99  9512.50  9179.99  9389.01   7936.988122
# 4 2018-04-28  8922.56  9447.00  8863.42  9329.99   8849.351945

# %%
# try get of OHLCV data for eah ticker in coin_list
"""
if exchange.has['fetchOHLCV']:
    for symbol in coin_list['ticker']:
        time.sleep (exchange.rateLimit / 1000) # time.sleep wants seconds
        print (symbol, exchange.fetch_ohlcv (symbol, '1d')) # one day
"""
# Out:
# "\nif exchange.has['fetchOHLCV']:\n    for symbol in coin_list['ticker']:\n        time.sleep (exchange.rateLimit / 1000) # time.sleep wants seconds\n        print (symbol, exchange.fetch_ohlcv (symbol, '1d')) # one day\n"

# %%
for exchange in exchanges:
    market = ccxt.exchange()

# %%
# production script

def get_coins(num_coins=500, sort_by_bottom=False, field='mktcap', base_curr='USD'):
    '''
    Gets the top (or bottom) N coins based on desired field: from API: CoinCap.io API (/front)
        Defaults to 'mktcap', Top 500
    Args: Number of coins to be returned
          Sort_method: top or bottom after sorting by desired field
          Fields: 'cap24hrChange', 'long', 'mktcap', 'perc', 'price', 'shapeshift',
       'short', 'supply', 'usdVolume', 'volume', 'vwapData', 'vwapDataBTC'
    Returns: Pandas DataFrame   
    '''
    req = requests.get('http://coincap.io/front')
    coin_json = req.json()
    coin_df = pd.DataFrame(coin_json)
    
    
    #check for null values
    for x in set(coin_df.isnull().sum()):
        if x != 0:
            print('WARNING: Requested data contains missing or corrupt data.')
    
    #sort by desired field
    coin_df.sort_values(field, ascending=sort_by_bottom)
    
    #slice the data, discard rest from memory
    coin_df[:num_coins]
    
    
    
    
    
    #add column for application symbol
    coin_df['ticker'] = coin_df['short'] +'/'+str(base_curr)
